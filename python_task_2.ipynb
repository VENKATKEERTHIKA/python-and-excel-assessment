# %%
import pandas as pd
import numpy as np
from datetime import time

# %%
df = pd.read_excel('dataset-3(1).xlsx')

# %%
df
# Out:
#     id_start   id_end  distance
# 0    1001400  1001402       9.7
# 1    1001402  1001404      20.2
# 2    1001404  1001406      16.0
# 3    1001406  1001408      21.7
# 4    1001408  1001410      11.1
# 5    1001410  1001412      15.6
# 6    1001412  1001414      18.2
# 7    1001414  1001416      13.2
# 8    1001416  1001418      13.6
# 9    1001418  1001420      12.9
# 10   1001420  1001422       9.6
# 11   1001422  1001424      11.4
# 12   1001424  1001426      18.6
# 13   1001426  1001428      15.8
# 14   1001428  1001430       8.6
# 15   1001430  1001432       9.0
# 16   1001432  1001434       7.9
# 17   1001434  1001436       4.0
# 18   1001436  1001438       9.0
# 19   1001436  1001437       5.0
# 20   1001438  1001437       4.0
# 21   1001438  1001440      10.0
# 22   1001440  1001442       3.9
# 23   1001442  1001488       4.5
# 24   1001488  1004356       4.0
# 25   1004356  1004354       2.0
# 26   1004354  1004355       2.0
# 27   1004355  1001444       0.7
# 28   1001444  1001446       6.6
# 29   1001446  1001448       9.6
# 30   1001448  1001450      15.7
# 31   1001450  1001452       9.9
# 32   1001452  1001454      11.3
# 33   1001454  1001456      13.6
# 34   1001456  1001458       8.9
# 35   1001458  1001460       5.1
# 36   1001460  1001461      12.8
# 37   1001460  1001462      17.9
# 38   1001461  1001462       5.1
# 39   1001462  1001464      26.7
# 40   1001464  1001466       8.5
# 41   1001466  1001468      10.7
# 42   1001468  1001470      10.6
# 43   1001470  1001472      16.0

# %% [markdown]
# Question 1: Distance Matrix Calculation

# %% [markdown]
# Create a function named calculate_distance_matrix that takes the dataset-3.csv as input and generates a DataFrame representing distances between IDs.
#
# The resulting DataFrame should have cumulative distances along known routes, with diagonal values set to 0. If distances between toll locations A to B and B to C are known, then the distance from A to C should be the sum of these distances. Ensure the matrix is symmetric, accounting for bidirectional distances between toll locations (i.e. A to B is equal to B to A).

# %%
def calculate_distance_matrix(df):
    # Create a DataFrame to store the distance matrix
    unique_ids = df[['id_start', 'id_end']].stack().unique()
    distance_matrix = pd.DataFrame(index=unique_ids, columns=unique_ids)

    # Initialize the distance matrix with zeros on the diagonal
    np.fill_diagonal(distance_matrix.values, 0)

    # Iterate through rows of the DataFrame to calculate distances
    for index, row in df.iterrows():
        id_start = int(row['id_start'])
        id_end = int(row['id_end'])
        distance = row['distance']

        # Check if the indices exist in the distance_matrix
        if id_start in distance_matrix.index and id_end in distance_matrix.index:
            # Update the distance matrix symmetrically
            distance_matrix.at[id_start, id_end] += distance
            distance_matrix.at[id_end, id_start] += distance

    return distance_matrix

# %%
results = calculate_distance_matrix(df)

# %%
results
# Out:
#         1001400 1001402 1001404 1001406 1001408 1001410 1001412 1001414  \
# 1001400       0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1
# 1001448     NaN     NaN     NaN     NaN
# 1001450     NaN     NaN     NaN     NaN
# 1001452     NaN     NaN     NaN     NaN
# 1001454     NaN     NaN     NaN     NaN
# 1001456     NaN     NaN     NaN     NaN
# 1001458     NaN     NaN     NaN     NaN
# 1001460     NaN     NaN     NaN     NaN
# 1001461     NaN     NaN     NaN     NaN
# 1001462     NaN     NaN     NaN     NaN
# 1001464     NaN     NaN     NaN     NaN
# 1001466       0     NaN     NaN     NaN
# 1001468     NaN       0     NaN     NaN
# 1001470     NaN     NaN       0     NaN
# 1001472     NaN     NaN     NaN       0
#
# [43 rows x 43 columns]

# %% [markdown]
# Question 2: Unroll Distance Matrix

# %% [markdown]
# Create a function unroll_distance_matrix that takes the DataFrame created in Question 1. The resulting DataFrame should have three columns: columns id_start, id_end, and distance.
#
# All the combinations except for same id_start to id_end must be present in the rows with their distance values from the input DataFrame.

# %%
def calculate_distance_matrix(df):
    # Create a DataFrame to store the distance matrix
    unique_ids = df[['id_start', 'id_end']].stack().unique()
    distance_matrix = pd.DataFrame(index=unique_ids, columns=unique_ids)

    # Initialize the distance matrix with zeros on the diagonal
    np.fill_diagonal(distance_matrix.values, 0)

    # Iterate through rows of the DataFrame to calculate distances
    for index, row in df.iterrows():
        id_start = int(row['id_start'])
        id_end = int(row['id_end'])
        distance = row['distance']

        # Check if the indices exist in the distance_matrix
        if id_start in distance_matrix.index and id_end in distance_matrix.index:
            # Update the distance matrix symmetrically
            distance_matrix.at[id_start, id_end] += distance
            distance_matrix.at[id_end, id_start] += distance
    return distance_matrix

# %%
results = calculate_distance_matrix(df)

# %%
results
# Out:
#         1001400 1001402 1001404 1001406 1001408 1001410 1001412 1001414  \
# 1001400       0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001402     NaN       0     NaN     NaN     NaN     NaN     NaN     NaN
# 1001404     NaN     NaN       0     NaN     NaN     NaN     NaN     NaN
# 1001406     NaN     NaN     NaN       0     NaN     NaN     NaN     NaN
# 1001408     NaN     NaN     NaN     NaN       0     NaN     NaN     NaN
# 1001410     NaN     NaN     NaN     NaN     NaN       0     NaN     NaN
# 1001412     NaN     NaN     NaN     NaN     NaN     NaN       0     NaN
# 1001414     NaN     NaN     NaN     NaN     NaN     NaN     NaN       0
# 1001416     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001418     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001420     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001422     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001424     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001426     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001428     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001430     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001432     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001434     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001436     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001438     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001437     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001440     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001442     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001488     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1004356     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1004354     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1004355     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001444     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001446     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001448     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001450     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001452     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001454     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001456     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001458     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001460     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001461     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001462     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001464     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001466     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001468     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001470     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001472     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#         1001416 1001418  ... 1001456 1001458 1001460 1001461 1001462 1001464  \
# 1001400     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001402     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001404     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001406     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001408     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001410     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001412     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001414     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001416       0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001418     NaN       0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001420     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001422     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001424     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001426     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001428     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001430     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001432     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001434     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001436     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001438     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001437     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001440     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001442     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1001488     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1004356     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 
    unrolled_df = pd.DataFrame(columns=['id_start', 'id_end', 'distance'])

    # Iterate through rows of the distance matrix
    for id_start in distance_matrix.index:
        for id_end in distance_matrix.columns:
            # Skip same id_start to id_end
            if id_start == id_end:
                continue

            # Get the distance value
            distance = distance_matrix.at[id_start, id_end]

            # Append the row to the unrolled DataFrame
            unrolled_df = unrolled_df.append({'id_start': id_start, 'id_end': id_end, 'distance': distance}, ignore_index=True)

    return unrolled_df

# %%
distance_matrix = calculate_distance_matrix(df)  # Assuming you have the distance matrix DataFrame
unrolled_df = unroll_distance_matrix(distance_matrix)
print(unrolled_df)
# Out:
#        id_start     id_end  distance
# 0     1001400.0  1001402.0       NaN
# 1     1001400.0  1001404.0       NaN
# 2     1001400.0  1001406.0       NaN
# 3     1001400.0  1001408.0       NaN
# 4     1001400.0  1001410.0       NaN
# ...         ...        ...       ...
# 1801  1001472.0  1001462.0       NaN
# 1802  1001472.0  1001464.0       NaN
# 1803  1001472.0  1001466.0       NaN
# 1804  1001472.0  1001468.0       NaN
# 1805  1001472.0  1001470.0       NaN
#
# [1806 rows x 3 columns]

# %% [markdown]
# Question 4: Calculate Toll Rate

# %% [markdown]
# Create a function calculate_toll_rate that takes the DataFrame created in Question 2 as input and calculates toll rates based on vehicle types.
#
# The resulting DataFrame should add 5 columns to the input DataFrame: moto, car, rv, bus, and truck with their respective rate coefficients. The toll rates should be calculated by multiplying the distance with the given rate coefficients for each vehicle type:
#
# 0.8 for moto
# 1.2 for car
# 1.5 for rv
# 2.2 for bus
# 3.6 for truck

# %%
def calculate_toll_rate(df):
    # Define rate coefficients for each vehicle type
    rate_coefficients = {'moto': 0.8, 'car': 1.2, 'rv': 1.5, 'bus': 2.2, 'truck': 3.6}

    # Create new columns for each vehicle type
    for vehicle_type, rate_coefficient in rate_coefficients.items():
        column_name = vehicle_type + '_toll'
        df[column_name] = df['distance'] * rate_coefficient

    return df

# %%
# Example usage
# Assuming df is the DataFrame from Question 2
df_with_toll_rates = calculate_toll_rate(df)
print(df_with_toll_rates)
# Out:
#     id_start   id_end  distance  moto_toll  car_toll  rv_toll  bus_toll  \
# 0    1001400  1001402       9.7       7.76     11.64    14.55     21.34
# 1    1001402  1001404      20.2      16.16     24.24    30.30     44.44
# 2    1001404  1001406      16.0      12.80     19.20    24.00     35.20
# 3    1001406  1001408      21.7      17.36     26.04    32.55     47.74
# 4    1001408  1001410      11.1       8.88     13.32    16.65     24.42
# 5    1001410  1001412      15.6      12.48     18.72    23.40     34.32
# 6    1001412  1001414      18.2      14.56     21.84    27.30     40.04
# 7    1001414  1001416      13.2      10.56     15.84    19.80     29.04
# 8    1001416  1001418      13.6      10.88     16.32    20.40     29.92
# 9    1001418  1001420      12.9      10.32     15.48    19.35     28.38
# 10   1001420  1001422       9.6       7.68     11.52    14.40     21.12
# 11   1001422  1001424      11.4       9.12     13.68    17.10     25.08
# 12   1001424  1001426      18.6      14.88     22.32    27.90     40.92
# 13   1001426  1001428      15.8      12.64     18.96    23.70     34.76
# 14   1001428  1001430       8.6       6.88     10.32    12.90     18.92
# 15   1001430  1001432       9.0       7.20     10.80    13.50     19.80
# 16   1001432  1001434       7.9       6.32      9.48    11.85     17.38
# 17   1001434  1001436       4.0       3.20      4.80     6.00      8.80
# 18   1001436  1001438       9.0       7.20     10.80    13.50     19.80
# 19   1001436  1001437       5.0       4.00      6.00     7.50     11.00
# 20   1001438  1001437       4.0       3.20      4.80     6.00      8.80
# 21   1001438  1001440      10.0       8.00     12.00    15.00     22.00
# 22   1001440  1001442       3.9       3.12      4.68     5.85      8.58
# 23   1001442  1001488       4.5       3.60      5.40     6.75      9.90
# 24   1001488  1004356       4.0       3.20      4.80     6.00      8.80
# 25   1004356  1004354       2.0       1.60      2.40     3.00      4.40
# 26   1004354  1004355       2.0       1.60      2.40     3.00      4.40
# 27   1004355  1001444       0.7       0.56      0.84     1.05      1.54
# 28   1001444  1001446       6.6       5.28      7.92     9.90     14.52
# 29   1001446  1001448       9.6       7.68     11.52    14.40     21.12
# 30   1001448  1001450      15.7      12.56     18.84    23.55     34.54
# 31   1001450  1001452       9.9       7.92     11.88    14.85     21.78
# 32   1001452  1001454      11.3       9.04     13.56    16.95     24.86
# 33   1001454  1001456      13.6      10.88     16.32    20.40     29.92
# 34   1001456  1001458       8.9       7.12     10.68    13.35     19.58
# 35   1001458  1001460       5.1       4.08      6.12     7.65     11.22
# 36   1001460  1001461      12.8      10.24     15.36    19.20     28.16
# 37   1001460  1001462      17.9      14.32     21.48    26.85     39.38
# 38   1001461  1001462       5.1       4.08      6.12     7.65     11.22
# 39   1001462  1001464      26.7      21.36     32.04    40.05     58.74
# 40   1001464  1001466       8.5       6.80     10.20    12.75     18.70
# 41   1001466  1001468      10.7       8.56     12.84    16.05     23.54
# 42   1001468  1001470      10.6       8.48     12.72    15.90     23.32
# 43   1001470  1001472      16.0      12.80     19.20    24.00     35.20
#
#     truck_toll
# 0        34.92
# 1        72.72
# 2        57.60
# 3        78.12
# 4        39.96
# 5        56.16
# 6        65.52
# 7        47.52
# 8        48.96
# 9        46.44
# 10       34.56
# 11       41.04
# 12       66.96
# 13       56.88
# 14       30.96
# 15       32.40
# 16       28.44
# 17       14.40
# 18       32.40
# 19       18.00
# 20       14.40
# 21       36.00
# 22       14.04
# 23       16.20
# 24       14.40
# 25        7.20
# 26        7.20
# 27        2.52
# 28       23.76
# 29       34.56
# 30       56.52
# 31       35.64
# 32       40.68
# 33       48.96
# 34       32.04
# 35       18.36
# 36       46.08
# 37       64.44
# 38       18.36
# 39       96.12
# 40       30.60
# 41       38.52
# 42       38.16
# 43       57.60
